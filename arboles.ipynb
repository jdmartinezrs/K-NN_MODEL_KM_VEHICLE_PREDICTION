# %% [markdown]
# <a href="https://colab.research.google.com/github/jdmartinezrs/incomesAndBillsProject/blob/main/arboles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![treee.png](data:image/png;base64,...)

# %% [markdown]
# A la izquierda los numeros son menores que el padre, ala derecha mayores que 6

# %%
logaritmo o(logn)

# %% [markdown]
# ![a1.png](data:image/png;base64,...)

# %% [markdown]
# Entre más desvalanceado más tiempo tomará - búqueda lineal

# %% [markdown]
# BUSQUEDA PROFUNDA DEEP-FIRST SEARCH

# %%
#Recursividad para navegar por los nodos
#funcion que se llama así misma pero con un condicional para salirnos del bucle

# %% [markdown]
# ![inorder.png](data:image/png;base64,...)

# %% [markdown]
# Va del nodo izquierdo, luego el nodo central y al final el de la derecha
#
# 1-4-5

# %% [markdown]
# ![ggg.png](data:image/png;base64,...)

# %% [markdown]
# 1,4,5,6,8,9

# %% [markdown]
# Orden en que se recorre

# %% [markdown]
# ![preorder.png](data:image/png;base64,...)

# %% [markdown]
# secuencia de recorrido preorder: 6,4,1,5,8,9

# %% [markdown]
# ![postorder.png](data:image/png;base64,...)

# %% [markdown]
# POSTORDER 1,5,4,9,8,6

# %% [markdown]
# INSERTAR

# %% [markdown]
# CONDICIONAL: VAL IZQUIERDA SEAN MENORES QUE EL VALOR CENTRAL, PERO QUE EL VALOR DE LOS NODOS DE LA DERECHA SEA MAYOR
