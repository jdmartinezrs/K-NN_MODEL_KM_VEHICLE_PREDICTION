# %% [markdown]
# <a href="https://colab.research.google.com/github/jdmartinezrs/incomesAndBillsProject/blob/main/DatasetPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %config IPCompleter.greedy=True
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xlrd
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# Upload Base de datos

# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/dataset_mantenimiento_vehiculos.xlsx")
df.shape
# Out:
# (1000, 9)

# %%
df
# Out:
#     ID_Vehículo     Marca_Modelo  Horas_Uso Componente_Afectado  \
# 0          V754       Volvo FH16        704   Sistema Eléctrico
# 1          V854       Volvo FH16       4967               Motor
# 2          V195  Mercedes Actros       2405              Frenos
# 3          V833    Iveco Stralis       3936         Transmisión
# 4          V877  Mercedes Actros       3962           Dirección
# ..          ...              ...        ...                 ...
# 995        V618       Volvo FH16       3706           Dirección
# 996        V884      Scania R500       3125               Motor
# 997        V957      Scania R500       3357       Refrigeración
# 998        V199          MAN TGX       3327           Dirección
# 999        V353  Mercedes Actros       3056              Frenos
#
#         Descripción_Falla  Presión_Aceite  Temperatura_Motor Código_Error  \
# 0    Problemas de batería            32.5                 85        P0172
# ...

# %%
datos = pd.DataFrame(df)
for i in range(1, 2):
  print(df.iloc[i])
# Out:
# presión Aceite: 29.3

# %%
from matplotlib import pyplot as plt
df['Presión_Aceite'].plot(kind='hist', bins=20, title='Presión_Aceite')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Marca_Modelo').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Horas_Uso'].plot(kind='hist', bins=20, title='Horas_Uso')
plt.gca().spines[['top', 'right',]].set_visible(False)
