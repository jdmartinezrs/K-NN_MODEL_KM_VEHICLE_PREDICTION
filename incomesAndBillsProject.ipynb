# %% [markdown]
# <a href="https://colab.research.google.com/github/jdmartinezrs/incomesAndBillsProject/blob/main/incomesAndBillsProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sbkñsmxfñbs{fns}
ydchkbljknñl.-

# %% [markdown]
# # Nueva sección
